# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# # Scraping

# %% [markdown]
# ## Classe odd HTML

# %%
url_base = "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/marktwerte/wettbewerb/BRA1/pos//detailpos/0/altersklasse/alle/plus/1/page/1"


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

response = requests.get(url_base, headers=headers)
soup = BeautifulSoup(response.text , 'html.parser')

tabela = soup.find_all('table')[1]

rows = tabela.find_all('tr', attrs={'class':'odd'})

data = []

for row in rows: #percorrendo as linhas, pegando os dados..
    data_rows = row.findAll('td')

    # Obter atributos específicos dentro das tags img
    img_data_src = row.find('img', {'class': 'bilderrahmen-fixed'}).get('data-src')
    img_src_flag = row.find('img', {'class': 'flaggenrahmen'}).get('src')
    img_src_club = row.find('img', {'class': ''}).get('src')
    club_name = row.find_all('a', {'title': True})[1].get('title')
    
    data_rows = [ele.text.strip() for ele in data_rows] # trazendo os textos dentro das tags
    data_row = [ele for ele in data_rows if ele]

    # Adicionar os atributos específicos à lista de dados
    data_row.extend([img_data_src, img_src_flag, img_src_club, club_name])
    
    data.append(data_row)

# Criar DataFrame
df = pd.DataFrame(data)
df
# Out:
#     0                                           1                       2   \
# 0    1                  Endrick \n\n\nCentroavante                 Endrick
# 1    3                    Pedro \n\n\nCentroavante                   Pedro
# 2    5          Luis Guilherme \n\n\nMeia Ofensivo          Luis Guilherme
# 3    7  Giorgian de Arrascaeta \n\n\nMeia Ofensivo  Giorgian de Arrascaeta
# 4    9              Gabriel Moscardo \n\n\nVolante        Gabriel Moscardo
# 5   11               Paulinho \n\n\nPonta Esquerda                Paulinho
# 6   13         Joaquín Piquerez \n\n\nLateral Esq.        Joaquín Piquerez
# 7   15           Luiz Henrique \n\n\nPonta Direita           Luiz Henrique
# 8   17                     Rony \n\n\nCentroavante                    Rony
# 9   19                 Estêvão \n\n\nPonta Direita                 Estêvão
# 10  21            Mathías Villasanti \n\n\nVolante      Mathías Villasanti
# 11  23                Everton \n\n\nPonta Esquerda                 Everton
# 12  25           Rodrigo Nestor \n\n\nMeia Central          Rodrigo Nestor
#
#                 3   4            5           6            7   \
# 0     Centroavante  17  45,00 mi. €  11/12/2023  45,00 mi. €
# 1     Centroavante  26  22,00 mi. €  11/12/2023  22,00 mi. €
# 2    Meia Ofensivo  18  17,00 mi. €  11/12/2023  17,00 mi. €
# 3    Meia Ofensivo  29  19,00 mi. €  11/12/2023  16,00 mi. €
# 4          Volante  18  15,00 mi. €  11/12/2023  15,00 mi. €
# 5   Ponta Esquerda  23  25,00 mi. €  11/12/2023  15,00 mi. €
# 6     Lateral Esq.  25  13,00 mi. €  11/12/2023  13,00 mi. €
# 7    Ponta Direita  23  15,00 mi. €  22/12/2023  12,00 mi. €
# 8     Centroavante  28  13,00 mi. €  11/12/2023  11,00 mi. €
# 9    Ponta Direita  16  10,00 mi. €  11/12/2023  10,00 mi. €
# 10         Volante  27  10,00 mi. €  11/12/2023  10,00 mi. €
# 11  Ponta Esquerda  27  40,00 mi. €  11/12/2023  10,00 mi. €
# 12    Meia Central  23   9,00 mi. €  11/12/2023   9,00 mi. €
#
#                                                    8   \
# 0   https://img.a.transfermarkt.technology/portrai...
# 1   https://img.a.transfermarkt.technology/portrai...
# 2   https://img.a.transfermarkt.technology/portrai...
# 3   https://img.a.transfermarkt.technology/portrai...
# 4   https://img.a.transfermarkt.technology/portrai...
# 5   https://img.a.transfermarkt.technology/portrai...
# 6   https://img.a.transfermarkt.technology/portrai...
# 7   https://img.a.transfermarkt.technology/portrai...
# 8   https://img.a.transfermarkt.technology/portrai...
# 9   https://img.a.transfermarkt.technology/portrai...
# 10  https://img.a.transfermarkt.technology/portrai...
# 11  https://img.a.transfermarkt.technology/portrai...
# 12  https://img.a.transfermarkt.technology/portrai...
#
#                                                    9   \
# 0   https://tmssl.akamaized.net/images/flagge/very...
# 1   https://tmssl.akamaized.net/images/flagge/very...
# 2   https://tmssl.akamaized.net/images/flagge/very...
# 3   https://tmssl.akamaized.net/images/flagge/very...
# 4   https://tmssl.akamaized.net/images/flagge/very...
# 5   https://tmssl.akamaized.net/images/flagge/very...
# 6   https://tmssl.akamaized.net/images/flagge/very...
# 7   https://tmssl.akamaized.net/images/flagge/very...
# 8   https://tmssl.akamaized.net/images/flagge/very...
# 9   https://tmssl.akamaized.net/images/flagge/very...
# 10  https://tmssl.akamaized.net/images/flagge/very...
# 11  https://tmssl.akamaized.net/images/flagge/very...
# 12  https://tmssl.akamaized.net/images/flagge/very...
#
#                                                    10                11
# 0   https://tmssl.akamaized.net/images/wappen/very...      SE Palmeiras
# 1   https://tmssl.akamaized.net/images/wappen/very...       CR Flamengo
# 2   https://tmssl.akamaized.net/images/wappen/very...      SE Palmeiras
# 3   https://tmssl.akamaized.net/images/wappen/very...       CR Flamengo
# 4   https://tmssl.akamaized.net/images/wappen/very...    SC Corinthians
# 5   https://tmssl.akamaized.net/images/wappen/very...  Atlético Mineiro
# 6   https://tmssl.akamaized.net/images/wappen/very...      SE Palmeiras
# 7   https://tmssl.akamaized.net/images/wappen/very...       Botafogo FR
# 8   https://tmssl.akamaized.net/images/wappen/very...      SE Palmeiras
# 9   https://tmssl.akamaized.net/images/wappen/very...      SE Palmeiras
# 10  https://tmssl.akamaized.net/images/wappen/very...       Grêmio FBPA
# 11  https://tmssl.akamaized.net/images/wappen/very...       CR Flamengo
# 12  https://tmssl.akamaized.net/images/wappen/very...      São Paulo FC

# %% [markdown]
# ### Generalizando páginas

# %%
# URLs das páginas
urls = [
    "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/marktwerte/wettbewerb/BRA1/pos//detailpos/0/altersklasse/alle/plus/1/page/{}".format(i) for i in range(1, 5)
]

# Lista vazia para armazenar DataFrames de todas as páginas
all_dfs = []

# Loop para iterar pelas URLs
for url in urls:
    
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extrair dados da página atual
    tabela = soup.find_all('table')[1]
    rows = tabela.find_all('tr', attrs={'class': 'odd'})
    data = []

    for row in rows:
        data_rows = row.findAll('td')

        # Obter atributos específicos dentro das tags img
        img_data_src = row.find('img', {'class': 'bilderrahmen-fixed'}).get('data-src')
        img_src_flag = row.find('img', {'class': 'flaggenrahmen'}).get('src')
        img_src_club = row.find('img', {'class': ''}).get('src')
        club_name = row.find_all('a', {'title': True})[1].get('title')

        data_rows = [ele.text.strip() for ele in data_rows] # trazendo os textos dentro das tags
        data_row = [ele for ele in data_rows if ele]

        # Adicionar os atributos específicos à lista de dados
        data_row.extend([img_data_src, img_src_flag, img_src_club,club_name])

        data.append(data_row)

    # Salvar os dados extraídos da página atual
    df_page = pd.DataFrame(data)

    # Adicionar DataFrame à lista
    all_dfs.append(df_page)

# Concatenar todos os DataFrames da lista
df_odd = pd.concat(all_dfs)

# Exibir o DataFrame final
df_odd
# Out:
#      0                                           1                       2   \
# 0     1                  Endrick \n\n\nCentroavante                 Endrick
# 1     3                    Pedro \n\n\nCentroavante                   Pedro
# 2     5          Luis Guilherme \n\n\nMeia Ofensivo          Luis Guilherme
# 3     7  Giorgian de Arrascaeta \n\n\nMeia Ofensivo  Giorgian de Arrascaeta
# 4     9              Gabriel Moscardo \n\n\nVolante        Gabriel Moscardo
# 5    11               Paulinho \n\n\nPonta Esquerda                Paulinho
# 6    13         Joaquín Piquerez \n\n\nLateral Esq.        Joaquín Piquerez
# 7    15           Luiz Henrique \n\n\nPonta Direita           Luiz Henrique
# 8    17                     Rony \n\n\nCentroavante                    Rony
ers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

response = requests.get(url_base, headers=headers)
soup = BeautifulSoup(response.text , 'html.parser')

tabela = soup.find_all('table')[1]

rows = tabela.find_all('tr', attrs={'class':'even'})

data = []

for row in rows: #percorrendo as linhas, pegando os dados..
    data_rows = row.findAll('td')

    # Obter atributos específicos dentro das tags img
    img_data_src = row.find('img', {'class': 'bilderrahmen-fixed'}).get('data-src')
    img_src_flag = row.find('img', {'class': 'flaggenrahmen'}).get('src')
    img_src_club = row.find('img', {'class': ''}).get('src')
    club_name = row.find_all('a', {'title': True})[1].get('title')

    data_rows = [ele.text.strip() for ele in data_rows] # trazendo os textos dentro das tags
    data_row = [ele for ele in data_rows if ele]

    # Adicionar os atributos específicos à lista de dados
    data_row.extend([img_data_src, img_src_flag, img_src_club, club_name])
    
    data.append(data_row)

# Criar DataFrame
df = pd.DataFrame(data)
df
# Out:
#     0                                       1                   2   \
# 0    2                     André \n\n\nVolante               André
# 1    4       Raphael Veiga \n\n\nMeia Ofensivo       Raphael Veiga
# 2    6      Gabriel Barbosa \n\n\nCentroavante     Gabriel Barbosa
# 3    8               Gerson \n\n\nMeia Central              Gerson
# 4   10         Yuri Alberto \n\n\nCentroavante        Yuri Alberto
# 5   12  Nicolás de la Cruz \n\n\nMeia Ofensivo  Nicolás de la Cruz
# 6   14                     Bento \n\n\nGoleiro               Bento
# 7   16                Pablo Maia \n\n\nVolante          Pablo Maia
# 8   18       Gabriel Menino \n\n\nMeia Central      Gabriel Menino
# 9   20      Guilherme Arana \n\n\nLateral Esq.     Guilherme Arana
# 10  22          Jhon Arias \n\n\nPonta Direita          Jhon Arias
# 11  24      Matías Zaracho \n\n\nMeia Ofensivo      Matías Zaracho
#
#                3   4            5           6            7   \
# 0         Volante  22  25,00 mi. €  11/12/2023  25,00 mi. €
# 1   Meia Ofensivo  28  18,00 mi. €  11/12/2023  18,00 mi. €
# 2    Centroavante  27  26,00 mi. €  11/12/2023  17,00 mi. €
# 3    Meia Central  26  22,00 mi. €  11/12/2023  15,00 mi. €
# 4    Centroavante  22  18,00 mi. €  11/12/2023  15,00 mi. €
# 5   Meia Ofensivo  26  18,00 mi. €  19/12/2023  14,00 mi. €
# 6         Goleiro  24  12,00 mi. €  11/12/2023  12,00 mi. €
# 7         Volante  22  11,00 mi. €  11/12/2023  11,00 mi. €
# 8    Meia Central  23  15,00 mi. €  11/12/2023  10,00 mi. €
# 9    Lateral Esq.  26  14,00 mi. €  11/12/2023  10,00 mi. €
# 10  Ponta Direita  26  10,00 mi. €  11/12/2023  10,00 mi. €
# 11  Meia Ofensivo  25  17,50 mi. €  11/12/2023   9,00 mi. €
#
#                                                    8   \
# 0   https://img.a.transfermarkt.technology/portrai...
# 1   https://img.a.transfermarkt.technology/portrai...
# 2   https://img.a.transfermarkt.technology/portrai...
# 3   https://img.a.transfermarkt.technology/portrai...
# 4   https://img.a.transfermarkt.technology/portrai...
# 5   https://img.a.transfermarkt.technology/portrai...
# 6   https://img.a.transfermarkt.technology/portrai...
# 7   https://img.a.transfermarkt.technology/portrai...
# 8   https://img.a.transfermarkt.technology/portrai...
# 9   https://img.a.transfermarkt.technology/portrai...
# 10  https://img.a.transfermarkt.technology/portrai...
# 11  https://img.a.transfermarkt.technology/portrai...
#
#                                                    9   \
# 0   https://tmssl.akamaized.net/images/flagge/very...
# 1   https://tmssl.akamaized.net/images/flagge/very...
# 2   https://tmssl.akamaized.net/images/flagge/very...
# 3   https://tmssl.akamaized.net/images/flagge/very...
# 4   https://tmssl.akamaized.net/images/flagge/very...
# 5   https://tmssl.akamaized.net/images/flagge/very...
# 6   https://tmssl.akamaized.net/images/flagge/very...
# 7   https://tmssl.akamaized.net/images/flagge/very...
# 8   https://tmssl.akamaized.net/images/flagge/very...
# 9   https://tmssl.akamaized.net/images/flagge/very...
# 10  https://tmssl.akamaized.net/images/flagge/very...
# 11  https://tmssl.akamaized.net/images/flagge/very...
#
#                                                    10                    11
# 0   https://tmssl.akamaized.net/images/wappen/very...         Fluminense FC
# 1   https://tmssl.akamaized.net/images/wappen/very...          SE Palmeiras
# 2   https://tmssl.akamaized.net/images/wappen/very...           CR Flamengo
# 3   https://tmssl.akamaized.net/images/wappen/very...           CR Flamengo
# 4   https://tmssl.akamaized.net/images/wappen/very...        SC Corinthians
# 5   https://tmssl.akamaized.net/images/wappen/very...           CR Flamengo
# 6   https://tmssl.akamaized.net/images/wappen/very...  Athletico Paranaense
# 7   https://tmssl.akamaized.net/images/wappen/very...          São Paulo FC
# 8   https://tmssl.akamaized.net/images/wappen/very...          SE Palmeiras
# 9   https://tmssl.akamaized.net/images/wappen/very...      Atlético Mineiro
# 10  https://tmssl.akamaized.net/images/wappen/very...         Fluminense FC
# 11  https://tmssl.akamaized.net/images/wappen/very...      Atlético Mineiro

# %% [markdown]
# ### Generalizando páginas

# %%
# URLs das páginas
urls = [
    "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/marktwerte/wettbewerb/BRA1/pos//detailpos/0/altersklasse/alle/plus/1/page/{}".format(i) for i in range(1, 5)
]

# Lista vazia para armazenar DataFrames de todas as páginas
all_dfs = []

# Loop para iterar pelas URLs
for url in urls:
    
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extrair dados da página atual
    tabela = soup.find_all('table')[1]
    rows = tabela.find_all('tr', attrs={'class': 'even'})
    data = []

    for row in rows:
        data_rows = row.findAll('td')

        # Obter atributos específicos dentro das tags img
        img_data_src = row.find('img', {'class': 'bilderrahmen-fixed'}).get('data-src')
        img_src_flag = row.find('img', {'class': 'flaggenrahmen'}).get('src')
        img_src_club = row.find('img', {'class': ''}).get('src')
        club_name = row.find_all('a', {'title': True})[1].get('title')


        data_rows = [ele.text.strip() for ele in data_rows] # trazendo os textos dentro das tags
        data_row = [ele for ele in data_rows if ele]

        # Adicionar os atributos específicos à lista de dados
        data_row.extend([img_data_src, img_src_flag, img_src_club, club_name])

        data.append(data_row)

    # Salvar os dados extraídos da página atual
    df_page = pd.DataFrame(data)

    # Adicionar DataFrame à lista
    all_dfs.append(df_page)

# Concatenar todos os DataFrames da lista
df_even = pd.concat(all_dfs)

# Exibir o DataFrame final
df_even
# Out:
#     0                                       1                   2   \
# 0    2                     André \n\n\nVolante               André
# 1    4       Raphael Veiga \n\n\nMeia Ofensivo       Raphael Veiga
# 2    6      Gabriel Barbosa \n\n\nCentroavante     Gabriel Barbosa
# 3    8               Gerson \n\n\nMeia Central              Gerson
# 4   10         Yuri Alberto \n\n\nCentroavante        Yuri Alberto
# 5   12  Nicolás de la Cruz \n\n\nMeia Ofensivo  Nicolás de la Cruz
# 6   14                     Bento \n\n\nGoleiro               Bento
# 7   16                Pablo Maia \n\n\nVolante          Pablo Maia
# 8   18       Gabriel Menino \n\n\nMeia Central      Gabriel Menino
# 9   20      Guilherme Arana \n\n\nLateral Esq.     Guilherme Arana
# 10  22          Jhon Arias \n\n\nPonta Direita          Jhon Arias
# 11  24      Matías Zaracho \n\n\nMeia Ofensivo      Matías Zaracho
# 0   27             Robert Renan \n\n\nZagueiro        Robert Renan
# 1   29            Gustavo Gómez \n\n\nZagueiro       Gustavo Gómez
# 2   31               Dudu \n\n\nPonta Esquerda                Dudu
# 3   33            Maurício \n\n\nMeia Ofensivo            Maurício
# 4   35    Franco Cristaldo \n\n\nMeia Ofensivo    Franco Cristaldo
# 5   37       Gabriel Veron \n\n\nPonta Direita       Gabriel Veron
# 6   39            Pedrinho \n\n\nPonta Direita            Pedrinho
# 7   41      Fabricio Bustos \n\n\nLateral Dir.     Fabricio Bustos
# 8   43         John Kennedy \n\n\nCentroavante        John Kennedy
# 9   45    Giuliano Galoppo \n\n\nMeia Ofensivo    Giuliano Galoppo
# 10  47             Aníbal Moreno \n\n\nVolante       Aníbal Moreno
# 11  49        Thiago Borbas \n\n\nCentroavante       Thiago Borbas
# 0   52       Rodrigo Garro \n\n\nMeia Ofensivo       Rodrigo Garro
# 1   54      Gustavo Scarpa \n\n\nMeia Ofensivo      Gustavo Scarpa
# 2   56           Jean Lucas \n\n\nMeia Central          Jean Lucas
# 3   58       Matheus França \n\n\nLateral Dir.      Matheus França
# 4   60             Félix Torres \n\n\nZagueiro        Félix Torres
://tmssl.akamaized.net/images/wappen/very...         Fluminense FC
# 1   https://tmssl.akamaized.net/images/wappen/very...          SE Palmeiras
# 2   https://tmssl.akamaized.net/images/wappen/very...           CR Flamengo
# 3   https://tmssl.akamaized.net/images/wappen/very...           CR Flamengo
# 4   https://tmssl.akamaized.net/images/wappen/very...        SC Corinthians
# 5   https://tmssl.akamaized.net/images/wappen/very...           CR Flamengo
# 6   https://tmssl.akamaized.net/images/wappen/very...  Athletico Paranaense
# 7   https://tmssl.akamaized.net/images/wappen/very...          São Paulo FC
# 8   https://tmssl.akamaized.net/images/wappen/very...          SE Palmeiras
# 9   https://tmssl.akamaized.net/images/wappen/very...      Atlético Mineiro
# 10  https://tmssl.akamaized.net/images/wappen/very...         Fluminense FC
# 11  https://tmssl.akamaized.net/images/wappen/very...      Atlético Mineiro
# 0   https://tmssl.akamaized.net/images/wappen/very...      SC Internacional
# 1   https://tmssl.akamaized.net/images/wappen/very...          SE Palmeiras
# 2   https://tmssl.akamaized.net/images/wappen/very...          SE Palmeiras
# 3   https://tmssl.akamaized.net/images/wappen/very...      SC Internacional
# 4   https://tmssl.akamaized.net/images/wappen/very...           Grêmio FBPA
# 5   https://tmssl.akamaized.net/images/wappen/very...           Cruzeiro EC
# 6   https://tmssl.akamaized.net/images/wappen/very...      Atlético Mineiro
# 7   https://tmssl.akamaized.net/images/wappen/very...      SC Internacional
# 8   https://tmssl.akamaized.net/images/wappen/very...         Fluminense FC
# 9   https://tmssl.akamaized.net/images/wappen/very...          São Paulo FC
# 10  https://tmssl.akamaized.net/images/wappen/very...          SE Palmeiras
# 11  https://tmssl.akamaized.net/images/wappen/very...         RB Bragantino
# 0   https://tmssl.akamaized.net/images/wappen/very...        SC Corinthians
# 1   https://tmssl.akamaized.net/images/wappen/very...      Atlético Mineiro
# 2   https://tmssl.akamaized.net/images/wappen/very...              EC Bahia
# 3   https://tmssl.akamaized.net/images/wappen/very...        SC Corinthians
# 4   https://tmssl.akamaized.net/images/wappen/very...        SC Corinthians
# 5   https://tmssl.akamaized.net/images/wappen/very...           CR Flamengo
# 6   https://tmssl.akamaized.net/images/wappen/very...         RB Bragantino
# 7   https://tmssl.akamaized.net/images/wappen/very...           CR Flamengo
# 8   https://tmssl.akamaized.net/images/wappen/very...          São Paulo FC
# 9   https://tmssl.akamaized.net/images/wappen/very...           Cruzeiro EC
# 10  https://tmssl.akamaized.net/images/wappen/very...        SC Corinthians
# 11  https://tmssl.akamaized.net/images/wappen/very...         Fluminense FC
# 0   https://tmssl.akamaized.net/images/wappen/very...           Grêmio FBPA
# 1   https://tmssl.akamaized.net/images/wappen/very...           Grêmio FBPA
# 2   https://tmssl.akamaized.net/images/wappen/very...           Grêmio FBPA
# 3   https://tmssl.akamaized.net/images/wappen/very...           CR Flamengo
# 4   https://tmssl.akamaized.net/images/wappen/very...           Botafogo FR
# 5   https://tmssl.akamaized.net/images/wappen/very...          São Paulo FC
# 6   https://tmssl.akamaized.net/images/wappen/very...         RB Bragantino
# 7   https://tmssl.akamaized.net/images/wappen/very...      Atlético Mineiro
# 8   https://tmssl.akamaized.net/images/wappen/very...      CR Vasco da Gama
# 9   https://tmssl.akamaized.net/images/wappen/very...      Atlético Mineiro
# 10  https://tmssl.akamaized.net/images/wappen/very...        SC Corinthians
# 11  https://tmssl.akamaized.net/images/wappen/very...          São Paulo FC

# %% [markdown]
# # Final- Concat Dataframes class Odd e Even

# %% [markdown]
# ## Concat Dataframes

# %%
import pandas as pd

# %%
df_final = pd.concat([df_odd, df_even], ignore_index=True)

# %%
df_final.head()
# Out:
#   0                                           1                       2   \
# 0  1                  Endrick \n\n\nCentroavante                 Endrick
# 1  3                    Pedro \n\n\nCentroavante                   Pedro
# 2  5          Luis Guilherme \n\n\nMeia Ofensivo          Luis Guilherme
# 3  7  Giorgian de Arrascaeta \n\n\nMeia Ofensivo  Giorgian de Arrascaeta
# 4  9              Gabriel Moscardo \n\n\nVolante        Gabriel Moscardo
#
#               3   4            5           6            7   \
# 0   Centroavante  17  45,00 mi. €  11/12/2023  45,00 mi. €
# 1   Centroavante  26  22,00 mi. €  11/12/2023  22,00 mi. €
# 2  Meia Ofensivo  18  17,00 mi. €  11/12/2023  17,00 mi. €
# 3  Meia Ofensivo  29  19,00 mi. €  11/12/2023  16,00 mi. €
# 4        Volante  18  15,00 mi. €  11/12/2023  15,00 mi. €
#
#                                                   8   \
# 0  https://img.a.transfermarkt.technology/portrai...
# 1  https://img.a.transfermarkt.technology/portrai...
# 2  https://img.a.transfermarkt.technology/portrai...
# 3  https://img.a.transfermarkt.technology/portrai...
# 4  https://img.a.transfermarkt.technology/portrai...
#
#                                                   9   \
# 0  https://tmssl.akamaized.net/images/flagge/very...
# 1  https://tmssl.akamaized.net/images/flagge/very...
# 2  https://tmssl.akamaized.net/images/flagge/very...
# 3  https://tmssl.akamaized.net/images/flagge/very...
# 4  https://tmssl.akamaized.net/images/flagge/very...
#
#                                                   10              11
# 0  https://tmssl.akamaized.net/images/wappen/very...    SE Palmeiras
# 1  https://tmssl.akamaized.net/images/wappen/very...     CR Flamengo
# 2  https://tmssl.akamaized.net/images/wappen/very...    SE Palmeiras
# 3  https://tmssl.akamaized.net/images/wappen/very...     CR Flamengo
# 4  https://tmssl.akamaized.net/images/wappen/very...  SC Corinthians

# %% [markdown]
# ## Pipeline

# %% [markdown]
# ### Renomear as colunas

# %%
df_final.columns = ['ranking', 'name_and_position', 'player_name', 'position', 'age', 'best_value_career', 'last_update', 'market_value', 'player_image', 'nation_image', 'club_image', 'club_name']

# %%
df_final.head(2)
# Out:
#   ranking           name_and_position player_name      position age  \
# 0       1  Endrick \n\n\nCentroavante     Endrick  Centroavante  17
# 1       3    Pedro \n\n\nCentroavante       Pedro  Centroavante  26
#
#   best_value_career last_update market_value  \
# 0       45,00 mi. €  11/12/2023  45,00 mi. €
# 1       22,00 mi. €  11/12/2023  22,00 mi. €
#
#                                         player_image  \
# 0  https://img.a.transfermarkt.technology/portrai...
# 1  https://img.a.transfermarkt.technology/portrai...
#
#                                         nation_image  \
# 0  https://tmssl.akamaized.net/images/flagge/very...
# 1  https://tmssl.akamaized.net/images/flagge/very...
#
#                                           club_image     club_name
# 0  https://tmssl.akamaized.net/images/wappen/very...  SE Palmeiras
# 1  https://tmssl.akamaized.net/images/wappen/very...   CR Flamengo

# %% [markdown]
# ### Remover coluna name_and_position

# %%
df_final = df_final.drop("name_and_position", axis=1, errors="ignore")

# %%
df_final.head(1)
# Out:
#   ranking player_name      position age best_value_career last_update  \
# 0       1     Endrick  Centroavante  17       45,00 mi. €  11/12/2023
#
#   market_value                                       player_image  \
# 0  45,00 mi. €  https://img.a.transfermarkt.technology/portrai...
#
#                                         nation_image  \
# 0  https://tmssl.akamaized.net/images/flagge/very...
#
#                                           club_image     club_name
# 0  https://tmssl.akamaized.net/images/wappen/very...  SE Palmeiras

# %% [markdown]
# ### Separar unidade nas colunas: best_value_career e market_value

# %%
import re

# Regex
def extrair_dados(valor):
    match = re.match(r'(\d+,\d+) mi. €', valor)
    if match:
        return match.group(1)
    else:
        return None


# Aplicar a função para extrair dados em ambas as colunas
df_final['best_value_career'] = df_final['best_value_career'].apply(extrair_dados)
df_final['market_value'] = df_final['market_value'].apply(extrair_dados)

# Criar as colunas moeda
df_final['currency_best_value_career'] = 'mi. €'
df_final['currency_market_value'] = 'mi. €'

# %%
df_final.head(1)
# Out:
#   ranking player_name      position age best_value_career last_update  \
# 0       1     Endrick  Centroavante  17             45,00  11/12/2023
#
#   market_value                                       player_image  \
# 0        45,00  https://img.a.transfermarkt.technology/portrai...
#
#                                         nation_image  \
# 0  https://tmssl.akamaized.net/images/flagge/very...
#
#                                           club_image     club_name  \
# 0  https://tmssl.akamaized.net/images/wappen/very...  SE Palmeiras
#
#   currency_best_value_career currency_market_value
# 0                      mi. €                 mi. €

# %% [markdown]
# ### Reordenar as colunas

# %%
# Lista com a ordem desejada das colunas
new_columns = ['ranking', 'player_name', 'position', 'age', 'club_name', 'best_value_career', 'currency_best_value_career', 'market_value', 'currency_market_value', 'player_image', 'nation_image', 'club_image', 'last_update']

# Reordenar as colunas
df_final = df_final[new_columns]

# %%
df_final.head(3)
# Out:
#   ranking     player_name       position age     club_name best_value_career  \
# 0       1         Endrick   Centroavante  17  SE Palmeiras             45,00
# 1       3           Pedro   Centroavante  26   CR Flamengo             22,00
# 2       5  Luis Guilherme  Meia Ofensivo  18  SE Palmeiras             17,00
#
#   currency_best_value_career market_value currency_market_value  \
# 0                      mi. €        45,00                 mi. €
# 1                      mi. €        22,00                 mi. €
# 2                      mi. €        17,00                 mi. €
#
#                                         player_image  \
# 0  https://img.a.transfermarkt.technology/portrai...
# 1  https://img.a.transfermarkt.technology/portrai...
# 2  https://img.a.transfermarkt.technology/portrai...
#
#                                         nation_image  \
# 0  https://tmssl.akamaized.net/images/flagge/very...
# 1  https://tmssl.akamaized.net/images/flagge/very...
# 2  https://tmssl.akamaized.net/images/flagge/very...
#
#                                           club_image last_update
# 0  https://tmssl.akamaized.net/images/wappen/very...  11/12/2023
# 1  https://tmssl.akamaized.net/images/wappen/very...  11/12/2023
# 2  https://tmssl.akamaized.net/images/wappen/very...  11/12/2023

# %% [markdown]
# ### Tipos de Dados

# %%
def transformar_colunas(df):

    # Antes da conversão alterar a vírgula por ponto nos valores
    df['best_value_career'] = df['best_value_career'].str.replace(',','.')
    df['market_value'] = df['market_value'].str.replace(',','.')

    
    df['ranking'] = pd.to_numeric(df['ranking'])
    df['age'] = pd.to_numeric(df['age'])
    df['best_value_career'] = pd.to_numeric(df['best_value_career'])
    df['market_value'] = pd.to_numeric(df['market_value'])
    df['last_update'] = pd.to_datetime(df['last_update'], format='%d/%m/%Y')

    return df


df_final = transformar_colunas(df_final)

# %%
df_final.dtypes
# Out:
# ranking                                int64
# player_name                           object
# position                              object
# age                                    int64
# club_name                             object
# best_value_career                    float64
# currency_best_value_career            object
# market_value                         float64
# currency_market_value                 object
# player_image                          object
# nation_image                          object
# club_image                            object
# last_update                   datetime64[ns]
# dtype: object

# %% [markdown]
# ### Sort o dataframe pelo ranking

# %%
df_final = df_final.sort_values('ranking', ascending=True).reset_index(drop=True)

# %%
df_final.head()
# Out:
#    ranking     player_name       position  age      club_name  \
# 0        1         Endrick   Centroavante   17   SE Palmeiras
# 1        2           André        Volante   22  Fluminense FC
# 2        3           Pedro   Centroavante   26    CR Flamengo
# 3        4   Raphael Veiga  Meia Ofensivo   28   SE Palmeiras
# 4        5  Luis Guilherme  Meia Ofensivo   18   SE Palmeiras
#
#    best_value_career currency_best_value_career  market_value  \
# 0               45.0                      mi. €          45.0
# 1               25.0                      mi. €          25.0
# 2               22.0                      mi. €          22.0
# 3               18.0                      mi. €          18.0
# 4               17.0                      mi. €          17.0
#
#   currency_market_value                                       player_image  \
# 0                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 1                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 2                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 3                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 4                 mi. €  https://img.a.transfermarkt.technology/portrai...
#
#                                         nation_image  \
# 0  https://tmssl.akamaized.net/images/flagge/very...
# 1  https://tmssl.akamaized.net/images/flagge/very...
# 2  https://tmssl.akamaized.net/images/flagge/very...
# 3  https://tmssl.akamaized.net/images/flagge/very...
# 4  https://tmssl.akamaized.net/images/flagge/very...
#
#                                           club_image last_update
# 0  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 1  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 2  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 3  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 4  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11

# %% [markdown]
# # Dataframe Final

# %%
df_final.head(10)
# Out:
#    ranking             player_name       position  age       club_name  \
# 0        1                 Endrick   Centroavante   17    SE Palmeiras
# 1        2                   André        Volante   22   Fluminense FC
# 2        3                   Pedro   Centroavante   26     CR Flamengo
# 3        4           Raphael Veiga  Meia Ofensivo   28    SE Palmeiras
# 4        5          Luis Guilherme  Meia Ofensivo   18    SE Palmeiras
# 5        6         Gabriel Barbosa   Centroavante   27     CR Flamengo
# 6        7  Giorgian de Arrascaeta  Meia Ofensivo   29     CR Flamengo
# 7        8                  Gerson   Meia Central   26     CR Flamengo
# 8        9        Gabriel Moscardo        Volante   18  SC Corinthians
# 9       10            Yuri Alberto   Centroavante   22  SC Corinthians
#
#    best_value_career currency_best_value_career  market_value  \
# 0               45.0                      mi. €          45.0
# 1               25.0                      mi. €          25.0
# 2               22.0                      mi. €          22.0
# 3               18.0                      mi. €          18.0
# 4               17.0                      mi. €          17.0
# 5               26.0                      mi. €          17.0
# 6               19.0                      mi. €          16.0
# 7               22.0                      mi. €          15.0
# 8               15.0                      mi. €          15.0
# 9               18.0                      mi. €          15.0
#
#   currency_market_value                                       player_image  \
# 0                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 1                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 2                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 3                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 4                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 5                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 6                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 7                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 8                 mi. €  https://img.a.transfermarkt.technology/portrai...
# 9                 mi. €  https://img.a.transfermarkt.technology/portrai...
#
#                                         nation_image  \
# 0  https://tmssl.akamaized.net/images/flagge/very...
# 1  https://tmssl.akamaized.net/images/flagge/very...
# 2  https://tmssl.akamaized.net/images/flagge/very...
# 3  https://tmssl.akamaized.net/images/flagge/very...
# 4  https://tmssl.akamaized.net/images/flagge/very...
# 5  https://tmssl.akamaized.net/images/flagge/very...
# 6  https://tmssl.akamaized.net/images/flagge/very...
# 7  https://tmssl.akamaized.net/images/flagge/very...
# 8  https://tmssl.akamaized.net/images/flagge/very...
# 9  https://tmssl.akamaized.net/images/flagge/very...
#
#                                           club_image last_update
# 0  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 1  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 2  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 3  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 4  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 5  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 6  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 7  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 8  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11
# 9  https://tmssl.akamaized.net/images/wappen/very...  2023-12-11

# %% [markdown]
# # Exportar CSV

# %%
path = '/home/vinicius/repos/pod_academy/web_scraping/dataset_final/transfermarket_players.csv'

df_final.to_csv(path, index=False)

# %% [markdown]
# # Conexão Banco de Dados
